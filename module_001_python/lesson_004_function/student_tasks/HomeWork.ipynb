# %% [markdown]
# # Задача 1
# Проектирование функций для построения обучающих моделей по данным. В данной задача вам нужно разработать прототипы функций(объявление функций без реализаций) для задачи анализа данных из машинного обучения, должны быть учтены следующие шаги:
# * Загрузка данных из внешних источников
# * Обработка не заданных значений - пропусков
# * Удаление не информативных признаков и объектов
# * Получение модели для обучения
# * Оценка качества модели
# * Сохранение модели в файл

# %%
def prototype(params1, lambda1):
    pass

prototype((1,2), lambda x: x/2)


def download_file(FileURL, wat_to_save, name_of_file="New file.txt"):
    """
        Описание:
    Данная функция реализует загрузку файла с внешнего источника.
    Функция ничего не возвращает.
    
        Параметры:
    FileURL(str) - ссылка на внешний источник,
    way_to_save(str) - путь к сохраняемому файлу,
    name_of_file(str) - имя сохраняемого файла. (По умолчанию: "New file.txt")
    
        Результат:
    Загружается файл с указанного URL в указанный путь для сохранения с требуемым именем 
    """
#Пример
#download_file("https://www.MachineLearning.com/Files/DataBase/ML152335493.txt", "C:\Users\UserName\workspace\ML\", "DataBase.txt") 

def processing_empty_symbols(way_to_file, kind_of_symbols, replacement_symbol="*"):
   
    """
        Описание:
    Данная функция заменяет не заданные значения на символ-флаг
    Функция ничего не возвращает.
    
        Параметры:
    way_to_file(str) - путь к файлу, который требуется обработать.
    kind_of_symbols(list) - список пропусков, подлежащих замене.  (пробел, ..., NONE, empty)
    replacement_symbol(list) - символ, подставляемый после замены. (по умолчанию: "*")
    
        Результат:
    В файле, размещенном по указанному пути меняются символы, обозначающие незаполненные/пустые поля на символ, задаваемый пользователем
    
     """
#Пример
# processing_empty_symbols("C:\Users\UserName\workspace\ML\DataBase.txt", ["...", "0", "EMPTY", "Нет значения", "NONE"], "@")

def clear_objects(way_to_file, kind_of_objects=[" ",",","."]):
    """
        Описание:
    Данная функция удаляет неинформативные объекты в файле.
    
        Параметры:
     way_to_file(str) - путь к файлу, в котором требуется удалить объекты.
     ind_of_objects(list) - список объектов, подлежащих удалению. (По умолчанию: " ", ",", ".")
         
         Результат:
     В файле по указанному пути удаляются указанные объекты.
     
    """
#Пример
#clear_objects("C:\Users\UserName\workspace\ML\DataBase.txt", [" ", "!"])

def give_model(way_to_file):
    """
        Описание:
    Данная программа загружает модель из файла в переменную model.
     
        Параметры:
    way_to_file(str) - путь к файлу с моделью.
    
        Переменные:
    model(list(list)) - сама модель, информация по всем нейронам.
    neuron(list) - информация по одному нейрону.
    weight(float) - вес.
        
        Результат:
    Возвращает список списков 
    model=[neuron_1=[weight_1, weight_2, weight_3...],
    neuron_2=[weight_1, weight_2, weight_3...],
    neuron_3=[weight_1, weight_2, weight_3...],
    ...]
        """
    return model
#Пример
#my_model=give_model("C:\Users\UserName\workspace\ML\DataBase.txt")

def ModelRating(model):
    """
        Описание:
    Данная функция проверяет качество модели на основе метода "трали-вали" и возвращает относительную оценку эффективности в диапазоне от 0 до 100.
    
        Параметры:
    model(list(list)) - модель для оценки.
    rating(float) - оценка эффективности модели.
    """
    return rating
#Пример
#my_rating=ModelRating([[1,0.1,0.4],[0,0.3,0.3],[1,0,0.5]])

def SaveModel(way_to_save, model, name_of_file="New file.txt", separator=", "):
    """
        Описание:
    Данная функция загружает модель в файл.
    
        Параметры:
    way_to_save(str) - путь для сохранения файла.
    model(list(list)) - модель для сохранения.
    name_of_file(str) - имя сохраняемого файла. (По умолчанию: "New file.txt")
    separator(str) - разделительный знак. (По умолчанию: ", ")
    
        Результат:
    Модель сохраняется в указанный файл с выбранным разделителем.

    """
#Пример
# SaveModel("C:\Users\UserName\workspace\ML\DataBase\", my_model, "Work001.txt")

# %% [markdown]
# # Задача 2
# Задача повышенной сложности. Реализовать вывод треугольника паскаля, через функцию. Пример треугольника:
# ![pascal triangle](pascal.png)
# Глубина 10 по умолчанию
